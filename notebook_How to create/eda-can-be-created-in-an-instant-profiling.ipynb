# %% [markdown]
# <a href="https://www.kaggle.com/code/risakashiwabara/profiling?scriptVersionId=169010425" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px">  1)environment setup　</p>

# %% [markdown]
# ## install(only for the first time)
#
# Python 3.8.5
#
# `pip install ydata-profiling`

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px">  Import Library　</p>

# %%
import ydata_profiling
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# /opt/conda/lib/python3.10/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /opt/conda/lib/python3.10/site-packages/visions/backends/shared/nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px">  2)Sample data acquisition</p>

# %%
df = pd.read_csv('/kaggle/input/tokyo-weatherdata/weather_tokyo_data.csv', encoding="shift-jis")

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px">  3)EDA Processing: ProfileReport</p>

# %%
profile = ProfileReport(df, title="weatherdata Report")

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.5.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-03-27 14:06:21.057345&quot;&gt;&lt;title&gt;weatherdata Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px">  4)output(HTML)</p>

# %%
profile.to_file('output.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px"> 5)If an error occurs</p>

# %% [markdown]
# `pip install --upgrade pip,`
#
# `pip install --upgrade Pillow,`

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/PrG6Lv3W/gahag-0091472394-1.png);font-family:Hiragino Sans;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px">WEATHER　Data </p>

# %%
from arrow import Arrow
df['Date'] = pd.to_datetime(df.apply(axis=1, func=lambda x: Arrow(year=x['year'], month=int(x['day'].split('/')[0]),
                                          day=int(x['day'].split('/')[1])).date()))
# and our temperature represents negative values with parentheses so we need to fix that
df['Temperature'] = df['temperature'].apply(lambda x: float(x.replace('(', '-').replace(')', '')))
df.columns = [item.strip() for item in df.columns]
df.head()
# Out:
#    year    day temperature  humidity  atmospheric pressure       Date  \
# 0  2022   11/6       13.5       61.0                1019.3 2022-11-06
# 1  2022   11/7       13.7       70.0                1018.9 2022-11-07
# 2  2022   11/8       15.9       55.0                1016.1 2022-11-08
# 3  2022   11/9       14.6       58.0                1022.2 2022-11-09
# 4  2022  11/10       15.2       64.0                1020.1 2022-11-10
#
#    Temperature
# 0         13.5
# 1         13.7
# 2         15.9
# 3         14.6
# 4         15.2

# %%
from plotly.express import scatter
scatter(data_frame=df, y='Temperature', x='humidity', color='atmospheric pressure')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import scatter
scatter(data_frame=df, y='atmospheric pressure', x='humidity', color='Temperature')
# Out:
# <div>                            <div id="c8d55736-a8a5-4f49-ae41-c8c2fa555044" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8d55736-a8a5-4f49-ae41-c8c2fa555044")) {                    Plotly.newPlot(                        "c8d55736-a8a5-4f49-ae41-c8c2fa555044",                        [{"hovertemplate":"humidity=%{x}\u003cbr\u003eatmospheric pressure=%{y}\u003cbr\u003eTemperature=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[13.5,13.7,15.9,14.6,15.2,16.1,16.6,18.0,16.1,11.1,12.4,12.8,13.2,13.7,11.6,13.4,15.4,11.7,15.3,13.5,12.7,14.4,11.7,16.7,16.6,10.1,9.4,7.8,10.2,7.6,6.1,8.5,9.3,9.3,10.4,9.5,8.2,7.2,9.2,7.0,8.2,6.7,6.5,4.9,5.4,6.5,7.2,5.4,6.2,6.9,6.3,6.8,6.5,8.1,6.6,5.7,6.6,6.2,5.8,5.6,5.9,5.3,6.
# ...

# %%
scatter(data_frame=df, x='Date', y='atmospheric pressure', trendline='rolling', trendline_options=dict(window=28), trendline_color_override='red')
# Out:
# <div>                            <div id="d9d1712f-0243-49ff-bbff-d53f13e4fdd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9d1712f-0243-49ff-bbff-d53f13e4fdd7")) {                    Plotly.newPlot(                        "d9d1712f-0243-49ff-bbff-d53f13e4fdd7",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eatmospheric pressure=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2022-11-06T00:00:00","2022-11-07T00:00:00","2022-11-08T00:00:00","2022-11-09T00:00:00","2022-11-10T00:00:00","2022-11-11T00:00:00","2022-11-12T00:00:00","2022-11-13T00:00:00","2022-11-14T00:00:00","2022-11-15T00:00:00","2022-
# ...
