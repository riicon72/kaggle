# %% [markdown]
# <a href="https://www.kaggle.com/code/risakashiwabara/eda-bergraph?scriptVersionId=156304762" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h1 style="font-family:verdana;"> <center>🌸bergraph🌸</center> </h1>
# <p><center style="color:Black; font-family:Cormorant Garamond; font-size:25px;text-align: left;">
# Recommended for the following people</center></p>
#
#
# <p><center style="color:Black; font-family:Cormorant Garamond; font-size:20px;text-align: left;">
# ・I want to make a graph.<br>
# ・I want to make a graph by age.<br>
# ・Looks like a brief overview.</center></p>
#
#
# <p><center style="color:#ff8c00; font-family:Cormorant Garamond; font-size:30px;">Thanks for visiting my notebook📖👀 </center></p>

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/mgw2KX0h/gahag-0109650987-1.png);font-family:Meiryo UI;font-size:120%;color:Black;text-align:center;border-radius:10px 50px; padding:8px">  Sample data acquisition</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ydata_profiling
from ydata_profiling import ProfileReport
# Out:
# /opt/conda/lib/python3.10/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /opt/conda/lib/python3.10/site-packages/visions/backends/shared/nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/mgw2KX0h/gahag-0109650987-1.png);font-family:camtasia;font-size:120%;color:Black;text-align:center;border-radius:15px 50px; padding:7px">  Sample data acquisition</p>

# %%
df = pd.read_csv('/kaggle/input/want-to-be-healthy/Frequency of weighing.csv')
df
# Out:
#    gender                      Frequency of weighing    age  \
# 0     man  Almost every day (at least 6 days a week)  20~29
# 1     man                          3-5 days per week  20~29
# 2     man                          1-2 days per week  20~29
# 3     man                         2-3 days per month  20~29
# 4     man                     Less than once a month  20~29
# 5   woman  Almost every day (at least 6 days a week)  20~29
# 6   woman                          3-5 days per week  20~29
# 7   woman                          1-2 days per week  20~29
# 8   woman                         2-3 days per month  20~29
# 9   woman                     Less than once a month  20~29
# 10    man  Almost every day (at least 6 days a week)  30~39
# 11    man                          3-5 days per week  30~39
# 12    man                          1-2 days per week  30~39
# 13    man                         2-3 days per month  30~39
# 14    man                     Less than once a month  30~39
# ...

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/mgw2KX0h/gahag-0109650987-1.png);font-family:camtasia;font-size:120%;color:Black;text-align:center;border-radius:15px 50px; padding:7px"> -Details-</p>

# %%
df.columns
# Out:
# Index(['gender', 'Frequency of weighing', 'age', 'the number of people'], dtype='object')

# %%
df.describe()
# Out:
#        the number of people
# count             60.000000
# mean             108.116667
# std               51.362484
# min               25.000000
# 25%               73.250000
# 50%               97.500000
# 75%              135.500000
# max              278.000000

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/mgw2KX0h/gahag-0109650987-1.png);font-family:camtasia;font-size:120%;color:Black;text-align:center;border-radius:15px 50px; padding:7px"> matplotlib-bergraph</p>

# %%
ber_df = pd.pivot_table(df, index='gender', columns='Frequency of weighing',  aggfunc=np.sum)
ber_df.plot.bar()
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
ber_df = pd.pivot_table(df, index='age', columns='Frequency of weighing',  aggfunc=np.sum)
ber_df.plot.bar()
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
ber_df = pd.pivot_table(df, index='Frequency of weighing', columns='gender',  aggfunc=np.sum)
ber_df.plot.bar()
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/mgw2KX0h/gahag-0109650987-1.png);font-family:Hiragino Sans;font-size:120%;color:B;text-align:center;border-radius:15px 50px; padding:7px">ProfileReport</p>

# %%
profile_train = ProfileReport(df, title="train_prediction-of-tourist-arrivals Report")
profile_train.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.5.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-24 13:10:24.647608&quot;&gt;&lt;title&gt;train_prediction-of-tourist-arrivals Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
